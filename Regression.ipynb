# %% [markdown]
# <a href="https://colab.research.google.com/github/Benji-Young/Regressions/blob/main/Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression, RidgeCV
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
# import the data
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

# Choose one feature
diabetes_X = diabetes_X[:, np.newaxis, 2]
diabetes_X.shape
# Out:
# (442, 1)

# %%
# Linear regression

# Split the data
X_train, X_test, y_train, y_test = train_test_split(diabetes_X, diabetes_y, test_size=0.2, random_state=4)

lin = LinearRegression()
lin.fit(X_train, y_train)
y_pred = lin.predict(X_test)

# The coefficients
print("Coefficients: \n", lin.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [923.51473399]
# Mean squared error: 3184.92
# Coefficient of determination: 0.42

# %%
# Plot the linear regression
plt.scatter(X_test, y_test, color="black")
plt.plot(X_test, y_pred, color="blue", linewidth=3)

#plt.xticks(())
#plt.yticks(())

plt.show()

# %%
# Ridge regression

# Split the data
X_train2, X_test2, y_train2, y_test2 = train_test_split(diabetes_X, diabetes_y, test_size=0.2, random_state=4)

rid = RidgeCV(alphas=np.array([0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1.0, 5.0, 1e10]))
print(X_train2.shape)
rid.fit(X_train2, y_train2)
y_pred2 = rid.predict(X_test2)

# The coefficients
print("Coefficients: \n", rid.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test2, y_pred2))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test2, y_pred2))
# Out:
# (353, 1)
# Coefficients:
#  [917.90633764]
# Mean squared error: 3188.22
# Coefficient of determination: 0.42

# %%
# Plot the Ridge regression
plt.scatter(X_test2, y_test2, color="black")
plt.plot(X_test2, y_pred2, color="blue", linewidth=3)

#plt.xticks(())
#plt.yticks(())

plt.show()
